# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
# 多行输出
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from fastai.basics import *
from fastai.tabular import *
# import modin.pandas as pd

# %% [markdown]
# # Rossmann 数据预处理

# %%
Config.data_path()
# Out:
# PosixPath('/home/lyc/.fastai/data')

# %%
ROOT = Config.data_path()/'rossmann'
table_names = ['train', 'store', 'store_states', 'state_names', 'googletrend', 'weather', 'test']
tables = [pd.read_csv(ROOT/f'{fname}.csv', low_memory=False) for fname in table_names]
train, store, store_states, state_names, googletrend, weather, test = tables
len(train),len(test)
# Out:
# (1017209, 41088)

# %%
train.head()
test.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0

# %% [markdown]
# - 使用 bool 值

# %%
train.StateHoliday = train.StateHoliday!='0'
test.StateHoliday = test.StateHoliday!='0'

# %%
train.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo  StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1         False
# 1      2          5  2015-07-31   6064        625     1      1         False
# 2      3          5  2015-07-31   8314        821     1      1         False
# 3      4          5  2015-07-31  13995       1498     1      1         False
# 4      5          5  2015-07-31   4822        559     1      1         False
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
store.head()
store_states.head()
state_names.head()
googletrend.head()
weather.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN
#    Store State
# 0      1    HE
# 1      2    TH
# 2      3    NW
# 3      4    BE
# 4      5    SN
#            StateName State
# 0  BadenWuerttemberg    BW
# 1             Bayern    BY
# 2             Berlin    BE
# 3        Brandenburg    BB
# 4             Bremen    HB
#              file                     week  trend
# 0  Rossmann_DE_SN  2012-12-02 - 2012-12-08     96
# 1  Rossmann_DE_SN  2012-12-09 - 2012-12-15     95
# 2  Rossmann_DE_SN  2012-12-16 - 2012-12-22     91
# 3  Rossmann_DE_SN  2012-12-23 - 2012-12-29     48
# 4  Rossmann_DE_SN  2012-12-30 - 2013-01-05     67
#                  file        Date  Max_TemperatureC  Mean_TemperatureC  \
# 0  NordrheinWestfalen  2013-01-01                 8                  4
# 1  NordrheinWestfalen  2013-01-02                 7                  4
# 2  NordrheinWestfalen  2013-01-03                11                  8
# 3  NordrheinWestfalen  2013-01-04                 9                  9
# 4  NordrheinWestfalen  2013-01-05                 8                  8
#
#    Min_TemperatureC  Dew_PointC  MeanDew_PointC  Min_DewpointC  Max_Humidity  \
# 0                 2           7               5              1            94
# 1                 1           5               3              2            93
# 2                 6          10               8              4           100
# 3                 8           9               9              8           100
# 4                 7           8               7              6           100
#
#    Mean_Humidity  ...  Max_VisibilityKm  Mean_VisibilityKm  Min_VisibilitykM  \
# 0             87  ...              31.0               12.0               4.0
# 1             85  ...              31.0               14.0              10.0
# 2             93  ...              31.0                8.0               2.0
# 3             94  ...              11.0                5.0               2.0
# 4             94  ...              10.0                6.0               3.0
#
#    Max_Wind_SpeedKm_h  Mean_Wind_SpeedKm_h  Max_Gust_SpeedKm_h  \
# 0                  39                   26                58.0
# 1                  24                   16                 NaN
# 2                  26                   21                 NaN
# 3                  23                   14                 NaN
# 4                  16                   10                 NaN
#
#    Precipitationmm  CloudCover  Events  WindDirDegrees
# 0             5.08         6.0    Rain             215
# 1             0.00         6.0    Rain             225
# 2             1.02         7.0    Rain             240
# 3             0.25         7.0    Rain             263
# 4             0.00         7.0    Rain             268
#
# [5 rows x 24 columns]

# %% [markdown]
# - 合并数据

# %%
def join_df(left, right, left_on, right_on=None, suffix='_y'):
    if right_on is None: right_on = left_on
    return left.merge(right, how='left', left_on=left_on, right_on=right_on, 
                      suffixes=("", suffix))

# %%
# ?pd.merge
# Out:
# Signature:
# pd.merge(
#     left,
#     right,
#     how='inner',
#     on=None,
#     left_on=None,
#     right_on=None,
#     left_index=False,
#     right_index=False,
#     sort=False,
#     suffixes=('_x', '_y'),
#     copy=True,
#     indicator=False,
#     validate=None,
# )
# Docstring:
# Merge DataFrame or named Series objects with a database-style join.
#
# The join is done on columns or indexes. If joining columns on
# columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
# on indexes or indexes on a column or columns, the index will be passed on.
#
# Parameters
# ----------
# left : DataFrame
# right : DataFrame or named Series
#     Object to merge with.
# how : {'left', 'right', 'outer', 'inner'}, default 'inner'
#     Type of merge to be performed.
#
#     * left: use only keys from left frame, similar to a SQL left outer join;
#       preserve key order.
#     * right: use only keys from right frame, similar to a SQL right outer join;
#       preserve key order.
#     * outer: use union of keys from both frames, similar to a SQL full outer
#       join; sort keys lexicographically.
#     * inner: use intersection of keys from both frames, similar to a SQL inner
#       join; preserve the order of the left keys.
# on : label or list
#     Column or index level names to join on. These must be found in both
#     DataFrames. If `on` is None and not merging on indexes then this defaults
#     to the intersection of the columns in both DataFrames.
# left_on : label or list, or array-like
#     Column or index level names to join on in the left DataFrame. Can also
#     be an array or list of arrays of the length of the left DataFrame.
#     These arrays are treated as if they are columns.
# right_on : label or list, or array-like
#     Column or index level names to join on in the right DataFrame. Can also
#     be an array or list of arrays of the length of the right DataFrame.
#     These arrays are treated as if they are columns.
# left_index : bool, default False
#     Use the index from the left DataFrame as the join key(s). If it is a
#     MultiIndex, the number of keys in the other DataFrame (either the index
#     or a number of columns) must match the number of levels.
# right_index : bool, default False
#     Use the index from the right DataFrame as the join key. Same caveats as
#     left_index.
# sort : bool, default False
#     Sort the join keys lexicographically in the result DataFrame. If False,
#     the order of the join keys depends on the join type (how keyword).
# suffixes : tuple of (str, str), default ('_x', '_y')
#     Suffix to apply to overlapping column names in the left and right
#     side, respectively. To raise an exception on overlapping columns use
#     (False, False).
# copy : bool, default True
#     If False, avoid copy if possible.
# indicator : bool or str, default False
#     If True, adds a column to output DataFrame called "_merge" with
#     information on the source of each row.
#     If string, column with information on source of each row will be added to
#     output DataFrame, and column will be named value of string.
#     Information column is Categorical-type and takes on a value of "left_only"
#     for observations whose merge key only appears in 'left' DataFrame,
#     "right_only" for observations whose merge key only appears in 'right'
#     DataFrame, and "both" if the observation's merge key is found in both.
#
# validate : str, optional
#     If specified, checks if merge is of specified type.
#
#     * "one_to_one" or "1:1": check if merge keys are unique in both
#       left and right datasets.
#     * "one_to_many" or "1:m": check if merge keys are unique in left
#       dataset.
#     * "many_to_one" or "m:1": check if merge keys are unique in right
#       dataset.
#     * "many_to_many" or "m:m": allowed, but does not result in checks.
#
#     .. versionadded:: 0.21.0
#
# Returns
# -------
# DataFrame
#     A DataFrame of the two merged objects.
#
# See Also
# --------
# merge_ordered : Merge with optional filling/interpolation.
# merge_asof : Merge on nearest keys.
# DataFrame.join : Similar method using indices.
#
# Notes
# -----
# Support for specifying index levels as the `on`, `left_on`, and
# `right_on` parameters was added in version 0.23.0
# Support for merging named Series objects was added in version 0.24.0
#
# Examples
# --------
#
# >>> df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
# ...                     'value': [1, 2, 3, 5]})
# >>> df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
# ...                     'value': [5, 6, 7, 8]})
# >>> df1
#     lkey value
# 0   foo      1
# 1   bar      2
# 2   baz      3
# 3   foo      5
# >>> df2
#     rkey value
# 0   foo      5
# 1   bar      6
# 2   baz      7
# 3   foo      8
#
# Merge df1 and df2 on the lkey and rkey columns. The value columns have
# the default suffixes, _x and _y, appended.
#
# >>> df1.merge(df2, left_on='lkey', right_on='rkey')
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        1  foo        8
# 2  foo        5  foo        5
# 3  foo        5  foo        8
# 4  bar        2  bar        6
# 5  baz        3  baz        7
#
# Merge DataFrames df1 and df2 with specified left and right suffixes
# appended to any overlapping columns.
#
# >>> df1.merge(df2, left_on='lkey', right_on='rkey',
# ...           suffixes=('_left', '_right'))
#   lkey  value_left rkey  value_right
# 0  foo           1  foo            5
# 1  foo           1  foo            8
# 2  foo           5  foo            5
# 3  foo           5  foo            8
# 4  bar           2  bar            6
# 5  baz           3  baz            7
#
# Merge DataFrames df1 and df2, but raise an exception if the DataFrames have
# any overlapping columns.
#
# >>> df1.merge(df2, left_on='lkey', right_on='rkey', suffixes=(False, False))
# Traceback (most recent call last):
# ...
# ValueError: columns overlap but no suffix specified:
#     Index(['value'], dtype='object')
# File:      ~/miniconda3/envs/torch36/lib/python3.6/site-packages/pandas/core/reshape/merge.py
# Type:      function

# %%
weather.columns
state_names.columns
# Out:
# Index(['file', 'Date', 'Max_TemperatureC', 'Mean_TemperatureC',
#        'Min_TemperatureC', 'Dew_PointC', 'MeanDew_PointC', 'Min_DewpointC',
#        'Max_Humidity', 'Mean_Humidity', 'Min_Humidity',
#        'Max_Sea_Level_PressurehPa', 'Mean_Sea_Level_PressurehPa',
#        'Min_Sea_Level_PressurehPa', 'Max_VisibilityKm', 'Mean_VisibilityKm',
#        'Min_VisibilitykM', 'Max_Wind_SpeedKm_h', 'Mean_Wind_SpeedKm_h',
#        'Max_Gust_SpeedKm_h', 'Precipitationmm', 'CloudCover', 'Events',
#        'WindDirDegrees'],
#       dtype='object')
# Index(['StateName', 'State'], dtype='object')

# %%
weather = join_df(weather, state_names, "file", "StateName")

# %%
weather.columns
state_names.columns
# Out:
# Index(['file', 'Date', 'Max_TemperatureC', 'Mean_TemperatureC',
#        'Min_TemperatureC', 'Dew_PointC', 'MeanDew_PointC', 'Min_DewpointC',
#        'Max_Humidity', 'Mean_Humidity', 'Min_Humidity',
#        'Max_Sea_Level_PressurehPa', 'Mean_Sea_Level_PressurehPa',
#        'Min_Sea_Level_PressurehPa', 'Max_VisibilityKm', 'Mean_VisibilityKm',
#        'Min_VisibilitykM', 'Max_Wind_SpeedKm_h', 'Mean_Wind_SpeedKm_h',
#        'Max_Gust_SpeedKm_h', 'Precipitationmm', 'CloudCover', 'Events',
#        'WindDirDegrees', 'StateName', 'State'],
#       dtype='object')
# Index(['StateName', 'State'], dtype='object')

# %%
weather.tail().T
# Out:
#                                  15835              15836       15837  \
# file                          Saarland           Saarland    Saarland
# Date                        2015-09-13         2015-09-14  2015-09-15
# Max_TemperatureC                    21                 18          16
# Mean_TemperatureC                   17                 14          12
# Min_TemperatureC                    12                 11           9
# Dew_PointC                          16                 15          11
# MeanDew_PointC                      14                 12           8
# Min_DewpointC                       12                  7           7
# Max_Humidity                       100                 99          93
# Mean_Humidity                       88                 85          77
# Min_Humidity                        68                 61          62
# Max_Sea_Level_PressurehPa         1015               1009        1010
# Mean_Sea_Level_PressurehPa        1010               1005        1008
# Min_Sea_Level_PressurehPa         1005               1004        1004
# Max_VisibilityKm                    31                 31          31
# Mean_VisibilityKm                   15                 13          12
# Min_VisibilitykM                    10                  4          10
# Max_Wind_SpeedKm_h                  27                 32          34
# Mean_Wind_SpeedKm_h                 10                 16          14
# Max_Gust_SpeedKm_h                  50                 53         NaN
# Precipitationmm                   1.02               9.91           0
# CloudCover                           7                  5           5
# Events                            Rain  Rain-Thunderstorm        Rain
# WindDirDegrees                     113                213         193
# StateName                     Saarland           Saarland    Saarland
# State                               SL                 SL          SL
#
#                                         15838       15839
# file                                 Saarland    Saarland
# Date                               2015-09-16  2015-09-17
# Max_TemperatureC                           19          14
# Mean_TemperatureC                          15          13
# Min_TemperatureC                           11          12
# Dew_PointC                                 16          14
# MeanDew_PointC                             13          12
# Min_DewpointC                              10          10
# Max_Humidity                               97          99
# Mean_Humidity                              90          92
# Min_Humidity                               75          82
# Max_Sea_Level_PressurehPa                1004        1013
# Mean_Sea_Level_PressurehPa                999        1005
# Min_Sea_Level_PressurehPa                 995         999
# Max_VisibilityKm                           31          31
# Mean_VisibilityKm                          10          14
# Min_VisibilitykM                            4           8
# Max_Wind_SpeedKm_h                         32          27
# Mean_Wind_SpeedKm_h                        14          16
# Max_Gust_SpeedKm_h                         45          47
# Precipitationmm                         20.07         6.1
# CloudCover                                  7           6
# Events                      Rain-Thunderstorm        Rain
# WindDirDegrees                            147         202
# StateName                            Saarland    Saarland
# State                                      SL          SL

# %%
googletrend.head()
# Out:
#              file                     week  trend
# 0  Rossmann_DE_SN  2012-12-02 - 2012-12-08     96
# 1  Rossmann_DE_SN  2012-12-09 - 2012-12-15     95
# 2  Rossmann_DE_SN  2012-12-16 - 2012-12-22     91
# 3  Rossmann_DE_SN  2012-12-23 - 2012-12-29     48
# 4  Rossmann_DE_SN  2012-12-30 - 2013-01-05     67

# %%
googletrend['Date'] = googletrend.week.str.split(' - ', expand=True)[0]
googletrend['State'] = googletrend.file.str.split('_', expand=True)[2]
googletrend.loc[googletrend.State=='NI', "State"] = 'HB,NI'

# %%
googletrend.head()
# Out:
#              file                     week  trend        Date State
# 0  Rossmann_DE_SN  2012-12-02 - 2012-12-08     96  2012-12-02    SN
# 1  Rossmann_DE_SN  2012-12-09 - 2012-12-15     95  2012-12-09    SN
# 2  Rossmann_DE_SN  2012-12-16 - 2012-12-22     91  2012-12-16    SN
# 3  Rossmann_DE_SN  2012-12-23 - 2012-12-29     48  2012-12-23    SN
# 4  Rossmann_DE_SN  2012-12-30 - 2013-01-05     67  2012-12-30    SN

# %%
def add_datepart(df, fldname, drop=True, time=False):
    "Helper function that adds columns relevant to a date."
    fld = df[fldname]
    fld_dtype = fld.dtype
    if isinstance(fld_dtype, pd.core.dtypes.dtypes.DatetimeTZDtype):
        fld_dtype = np.datetime64

    if not np.issubdtype(fld_dtype, np.datetime64):
        df[fldname] = fld = pd.to_datetime(fld, infer_datetime_format=True)
    targ_pre = re.sub('[Dd]ate$', '', fldname)
    attr = ['Year', 'Month', 'Week', 'Day', 'Dayofweek', 'Dayofyear',
            'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start']
    if time: attr = attr + ['Hour', 'Minute', 'Second']
    for n in attr: df[targ_pre + n] = getattr(fld.dt, n.lower())
    df[targ_pre + 'Elapsed'] = fld.astype(np.int64) // 10 ** 9
    if drop: df.drop(fldname, axis=1, inplace=True)

# %%
add_datepart(weather, "Date", drop=False)
add_datepart(googletrend, "Date", drop=False)
add_datepart(train, "Date", drop=False)
add_datepart(test, "Date", drop=False)

# %%
weather.head().T
# Out:
#                                               0                    1  \
# file                         NordrheinWestfalen   NordrheinWestfalen
# Date                        2013-01-01 00:00:00  2013-01-02 00:00:00
# Max_TemperatureC                              8                    7
# Mean_TemperatureC                             4                    4
# Min_TemperatureC                              2                    1
# Dew_PointC                                    7                    5
# MeanDew_PointC                                5                    3
# Min_DewpointC                                 1                    2
# Max_Humidity                                 94                   93
# Mean_Humidity                                87                   85
# Min_Humidity                                 65                   78
# Max_Sea_Level_PressurehPa                  1013                 1028
# Mean_Sea_Level_PressurehPa                 1005                 1022
# Min_Sea_Level_PressurehPa                  1001                 1014
# Max_VisibilityKm                             31                   31
# Mean_VisibilityKm                            12                   14
# Min_VisibilitykM                              4                   10
# Max_Wind_SpeedKm_h                           39                   24
# Mean_Wind_SpeedKm_h                          26                   16
# Max_Gust_SpeedKm_h                           58                  NaN
# Precipitationmm                            5.08                    0
# CloudCover                                    6                    6
# Events                                     Rain                 Rain
# WindDirDegrees                              215                  225
# StateName                    NordrheinWestfalen   NordrheinWestfalen
# State                                        NW                   NW
# Year                                       2013                 2013
# Month                                         1                    1
# Week                                          1                    1
# Day                                           1                    2
# Dayofweek                                     1                    2
# Dayofyear                                     1                    2
# Is_month_end                              False                False
# Is_month_start                             True                False
# Is_quarter_end                            False                False
# Is_quarter_start                           True                False
# Is_year_end                               False                False
# Is_year_start                              True                False
# Elapsed                              1356998400           1357084800
#
#                                               2                    3  \
# file                         NordrheinWestfalen   NordrheinWestfalen
# Date                        2013-01-03 00:00:00  2013-01-04 00:00:00
# Max_TemperatureC                             11                    9
# Mean_TemperatureC                             8                    9
# Min_TemperatureC                              6                    8
# Dew_PointC                                   10                    9
# MeanDew_PointC                                8                    9
# Min_DewpointC                                 4                    8
# Max_Humidity                                100                  100
# Mean_Humidity                                93                   94
# Min_Humidity                                 77                   87
# Max_Sea_Level_PressurehPa                  1035                 1036
# Mean_Sea_Level_PressurehPa                 1030                 1035
# Min_Sea_Level_PressurehPa                  1026                 1034
# Max_VisibilityKm                             31                   11
# Mean_VisibilityKm                             8                    5
# Min_VisibilitykM                              2                    2
# Max_Wind_SpeedKm_h                           26                   23
# Mean_Wind_SpeedKm_h                          21                   14
# Max_Gust_SpeedKm_h                          NaN                  NaN
# Precipitationmm                            1.02                 0.25
# CloudCover                                    7                    7
# Events                                     Rain                 Rain
# WindDirDegrees                              240                  263
# StateName                    NordrheinWestfalen   NordrheinWestfalen
# State                                        NW                   NW
# Year                                       2013                 2013
# Month                                         1                    1
# Week                                          1                    1
# Day                                           3                    4
# Dayofweek                                     3                    4
# Dayofyear                                     3                    4
# Is_month_end                              False                False
# Is_month_start                            False                False
# Is_quarter_end                            False                False
# Is_quarter_start                          False                False
# Is_year_end                               False                False
# Is_year_start                             False                False
# Elapsed                              1357171200           1357257600
#
#                                               4
# file                         NordrheinWestfalen
# Date                        2013-01-05 00:00:00
# Max_TemperatureC                              8
# Mean_TemperatureC                             8
# Min_TemperatureC                              7
# Dew_PointC                                    8
# MeanDew_PointC                                7
# Min_DewpointC                                 6
# Max_Humidity                                100
# Mean_Humidity                                94
# Min_Humidity                                 87
# Max_Sea_Level_PressurehPa                  1035
# Mean_Sea_Level_PressurehPa                 1034
# Min_Sea_Level_PressurehPa                  1033
# Max_VisibilityKm                             10
# Mean_VisibilityKm                             6
# Min_VisibilitykM                              3
# Max_Wind_SpeedKm_h                           16
# Mean_Wind_SpeedKm_h                          10
# Max_Gust_SpeedKm_h                          NaN
# Precipitationmm                               0
# CloudCover                                    7
# Events                                     Rain
# WindDirDegrees                              268
# StateName                    NordrheinWestfalen
# State                                        NW
# Year                                       2013
# Month                                         1
# Week                                          1
# Day                                           5
# Dayofweek                                     5
# Dayofyear                                     5
# Is_month_end                              False
# Is_month_start                            False
# Is_quarter_end                            False
# Is_quarter_start                          False
# Is_year_end                               False
# Is_year_start                             False
# Elapsed                              1357344000

# %%
googletrend.head()
# Out:
#              file                     week  trend       Date State  Year  \
# 0  Rossmann_DE_SN  2012-12-02 - 2012-12-08     96 2012-12-02    SN  2012
# 1  Rossmann_DE_SN  2012-12-09 - 2012-12-15     95 2012-12-09    SN  2012
# 2  Rossmann_DE_SN  2012-12-16 - 2012-12-22     91 2012-12-16    SN  2012
# 3  Rossmann_DE_SN  2012-12-23 - 2012-12-29     48 2012-12-23    SN  2012
# 4  Rossmann_DE_SN  2012-12-30 - 2013-01-05     67 2012-12-30    SN  2012
#
#    Month  Week  Day  Dayofweek  Dayofyear  Is_month_end  Is_month_start  \
# 0     12    48    2          6        337         False           False
# 1     12    49    9          6        344         False           False
# 2     12    50   16          6        351         False           False
# 3     12    51   23          6        358         False           False
# 4     12    52   30          6        365         False           False
#
#    Is_quarter_end  Is_quarter_start  Is_year_end  Is_year_start     Elapsed
# 0           False             False        False          False  1354406400
# 1           False             False        False          False  1355011200
# 2           False             False        False          False  1355616000
# 3           False             False        False          False  1356220800
# 4           False             False        False          False  1356825600

# %%
trend_de = googletrend[googletrend.file == 'Rossmann_DE']

# %%
store = join_df(store, store_states, "Store")
len(store[store.State.isnull()])
# Out:
# 0

# %%
store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval State
# 0              NaN    HE
# 1  Jan,Apr,Jul,Oct    TH
# 2  Jan,Apr,Jul,Oct    NW
# 3              NaN    BE
# 4              NaN    SN

# %%
joined = join_df(train, store, "Store")
joined_test = join_df(test, store, "Store")
len(joined[joined.StoreType.isnull()]),len(joined_test[joined_test.StoreType.isnull()])
# Out:
# (0, 0)

# %%
joined.head().T
# Out:
#                                              0                    1  \
# Store                                        1                    2
# DayOfWeek                                    5                    5
# Date                       2015-07-31 00:00:00  2015-07-31 00:00:00
# Sales                                     5263                 6064
# Customers                                  555                  625
# Open                                         1                    1
# Promo                                        1                    1
# StateHoliday                             False                False
# SchoolHoliday                                1                    1
# Year                                      2015                 2015
# Month                                        7                    7
# Week                                        31                   31
# Day                                         31                   31
# Dayofweek                                    4                    4
# Dayofyear                                  212                  212
# Is_month_end                              True                 True
# Is_month_start                           False                False
# Is_quarter_end                           False                False
# Is_quarter_start                         False                False
# Is_year_end                              False                False
# Is_year_start                            False                False
# Elapsed                             1438300800           1438300800
# StoreType                                    c                    a
# Assortment                                   a                    a
# CompetitionDistance                       1270                  570
# CompetitionOpenSinceMonth                    9                   11
# CompetitionOpenSinceYear                  2008                 2007
# Promo2                                       0                    1
# Promo2SinceWeek                            NaN                   13
# Promo2SinceYear                            NaN                 2010
# PromoInterval                              NaN      Jan,Apr,Jul,Oct
# State                                       HE                   TH
#
#                                              2                    3  \
# Store                                        3                    4
# DayOfWeek                                    5                    5
# Date                       2015-07-31 00:00:00  2015-07-31 00:00:00
# Sales                                     8314                13995
# Customers                                  821                 1498
# Open                                         1                    1
# Promo                                        1                    1
# StateHoliday                             False                False
# SchoolHoliday                                1                    1
# Year                                      2015                 2015
# Month                                        7                    7
# Week                                        31                   31
# Day                                         31                   31
# Dayofweek                                    4                    4
# Dayofyear                                  212                  212
# Is_month_end                              True                 True
# Is_month_start                           False                False
# Is_quarter_end                           False                False
# Is_quarter_start                         False                False
# Is_year_end                              False                False
# Is_year_start                            False                False
# Elapsed                             1438300800           1438300800
# StoreType                                    a                    c
# Assortment                                   a                    c
# CompetitionDistance                      14130                  620
# CompetitionOpenSinceMonth                   12                    9
# CompetitionOpenSinceYear                  2006                 2009
# Promo2                                       1                    0
# Promo2SinceWeek                             14                  NaN
# Promo2SinceYear                           2011                  NaN
# PromoInterval                  Jan,Apr,Jul,Oct                  NaN
# State                                       NW                   BE
#
#                                              4
# Store                                        5
# DayOfWeek                                    5
# Date                       2015-07-31 00:00:00
# Sales                                     4822
# Customers                                  559
# Open                                         1
# Promo                                        1
# StateHoliday                             False
# SchoolHoliday                                1
# Year                                      2015
# Month                                        7
# Week                                        31
# Day                                         31
# Dayofweek                                    4
# Dayofyear                                  212
# Is_month_end                              True
# Is_month_start                           False
# Is_quarter_end                           False
# Is_quarter_start                         False
# Is_year_end                              False
# Is_year_start                            False
# Elapsed                             1438300800
# StoreType                                    a
# Assortment                                   a
# CompetitionDistance                      29910
# CompetitionOpenSinceMonth                    4
# CompetitionOpenSinceYear                  2015
# Promo2                                       0
# Promo2SinceWeek                            NaN
# Promo2SinceYear                            NaN
# PromoInterval                              NaN
# State                                       SN

# %%
joined_test.head().T
# Out:
#                                              0                    1  \
# Id                                           1                    2
# Store                                        1                    3
# DayOfWeek                                    4                    4
# Date                       2015-09-17 00:00:00  2015-09-17 00:00:00
# Open                                         1                    1
# Promo                                        1                    1
# StateHoliday                             False                False
# SchoolHoliday                                0                    0
# Year                                      2015                 2015
# Month                                        9                    9
# Week                                        38                   38
# Day                                         17                   17
# Dayofweek                                    3                    3
# Dayofyear                                  260                  260
# Is_month_end                             False                False
# Is_month_start                           False                False
# Is_quarter_end                           False                False
# Is_quarter_start                         False                False
# Is_year_end                              False                False
# Is_year_start                            False                False
# Elapsed                             1442448000           1442448000
# StoreType                                    c                    a
# Assortment                                   a                    a
# CompetitionDistance                       1270                14130
# CompetitionOpenSinceMonth                    9                   12
# CompetitionOpenSinceYear                  2008                 2006
# Promo2                                       0                    1
# Promo2SinceWeek                            NaN                   14
# Promo2SinceYear                            NaN                 2011
# PromoInterval                              NaN      Jan,Apr,Jul,Oct
# State                                       HE                   NW
#
#                                              2                    3  \
# Id                                           3                    4
# Store                                        7                    8
# DayOfWeek                                    4                    4
# Date                       2015-09-17 00:00:00  2015-09-17 00:00:00
# Open                                         1                    1
# Promo                                        1                    1
# StateHoliday                             False                False
# SchoolHoliday                                0                    0
# Year                                      2015                 2015
# Month                                        9                    9
# Week                                        38                   38
# Day                                         17                   17
# Dayofweek                                    3                    3
# Dayofyear                                  260                  260
# Is_month_end                             False                False
# Is_month_start                           False                False
# Is_quarter_end                           False                False
# Is_quarter_start                         False                False
# Is_year_end                              False                False
# Is_year_start                            False                False
# Elapsed                             1442448000           1442448000
# StoreType                                    a                    a
# Assortment                                   c                    a
# CompetitionDistance                      24000                 7520
# CompetitionOpenSinceMonth                    4                   10
# CompetitionOpenSinceYear                  2013                 2014
# Promo2                                       0                    0
# Promo2SinceWeek                            NaN                  NaN
# Promo2SinceYear                            NaN                  NaN
# PromoInterval                              NaN                  NaN
# State                                       SH                   SH
#
#                                              4
# Id                                           5
# Store                                        9
# DayOfWeek                                    4
# Date                       2015-09-17 00:00:00
# Open                                         1
# Promo                                        1
# StateHoliday                             False
# SchoolHoliday                                0
# Year                                      2015
# Month                                        9
# Week                                        38
# Day                                         17
# Dayofweek                                    3
# Dayofyear                                  260
# Is_month_end                             False
# Is_month_start                           False
# Is_quarter_end                           False
# Is_quarter_start                         False
# Is_year_end                              False
# Is_year_start                            False
# Elapsed                             1442448000
# StoreType                                    a
# Assortment                                   c
# CompetitionDistance                       2030
# CompetitionOpenSinceMonth                    8
# CompetitionOpenSinceYear                  2000
# Promo2                                       0
# Promo2SinceWeek                            NaN
# Promo2SinceYear                            NaN
# PromoInterval                              NaN
# State                                       NW

# %%
joined = join_df(joined, googletrend, ["State","Year", "Week"])
joined_test = join_df(joined_test, googletrend, ["State","Year", "Week"])
len(joined[joined.trend.isnull()]),len(joined_test[joined_test.trend.isnull()])
# Out:
# (0, 0)

# %%
joined = joined.merge(trend_de, 'left', ["Year", "Week"], suffixes=('', '_DE'))
joined_test = joined_test.merge(trend_de, 'left', ["Year", "Week"], suffixes=('', '_DE'))
len(joined[joined.trend_DE.isnull()]),len(joined_test[joined_test.trend_DE.isnull()])
# Out:
# (0, 0)

# %%
joined = join_df(joined, weather, ["State","Date"])
joined_test = join_df(joined_test, weather, ["State","Date"])
len(joined[joined.Mean_TemperatureC.isnull()]),len(joined_test[joined_test.Mean_TemperatureC.isnull()])
# Out:
# (0, 0)

# %%
joined.head().T
# Out:
#                                               0                    1  \
# Store                                         1                    2
# DayOfWeek                                     5                    5
# Date                        2015-07-31 00:00:00  2015-07-31 00:00:00
# Sales                                      5263                 6064
# Customers                                   555                  625
# Open                                          1                    1
# Promo                                         1                    1
# StateHoliday                              False                False
# SchoolHoliday                                 1                    1
# Year                                       2015                 2015
# Month                                         7                    7
# Week                                         31                   31
# Day                                          31                   31
# Dayofweek                                     4                    4
# Dayofyear                                   212                  212
# Is_month_end                               True                 True
# Is_month_start                            False                False
# Is_quarter_end                            False                False
# Is_quarter_start                          False                False
# Is_year_end                               False                False
# Is_year_start                             False                False
# Elapsed                              1438300800           1438300800
# StoreType                                     c                    a
# Assortment                                    a                    a
# CompetitionDistance                        1270                  570
# CompetitionOpenSinceMonth                     9                   11
# CompetitionOpenSinceYear                   2008                 2007
# Promo2                                        0                    1
# Promo2SinceWeek                             NaN                   13
# Promo2SinceYear                             NaN                 2010
# ...                                         ...                  ...
# Max_Humidity                                 98                  100
# Mean_Humidity                                54                   62
# Min_Humidity                                 18                   25
# Max_Sea_Level_PressurehPa                  1021                 1021
# Mean_Sea_Level_PressurehPa                 1018                 1019
# Min_Sea_Level_PressurehPa                  1015                 1017
# Max_VisibilityKm                             31                   10
# Mean_VisibilityKm                            15                   10
# Min_VisibilitykM                             10                   10
# Max_Wind_SpeedKm_h                           24                   14
# Mean_Wind_SpeedKm_h                          11                   11
# Max_Gust_SpeedKm_h                          NaN                  NaN
# Precipitationmm                               0                    0
# CloudCover                                    1                    4
# Events                                      Fog                  Fog
# WindDirDegrees                               13                  309
# StateName                                Hessen           Thueringen
# Year_y                                     2015                 2015
# Month_y                                       7                    7
# Week_y                                       31                   31
# Day_y                                        31                   31
# Dayofweek_y                                   4                    4
# Dayofyear_y                                 212                  212
# Is_month_end_y                             True                 True
# Is_month_start_y                          False                False
# Is_quarter_end_y                          False                False
# Is_quarter_start_y                        False                False
# Is_year_end_y                             False                False
# Is_year_start_y                           False                False
# Elapsed_y                            1438300800           1438300800
#
#                                               2                    3  \
# Store                                         3                    4
# DayOfWeek                                     5                    5
# Date                        2015-07-31 00:00:00  2015-07-31 00:00:00
# Sales                                      8314                13995
# Customers                                   821                 1498
# Open                                          1                    1
# Promo                                         1                    1
# StateHoliday                              False                False
# SchoolHoliday                                 1                    1
# Year                                       2015                 2015
# Month                                         7                    7
# Week                                         31                   31
# Day                                          31                   31
# Dayofweek                                     4                    4
# Dayofyear                                   212                  212
# Is_month_end                               True                 True
# Is_month_start                            False                False
# Is_quarter_end                            False                False
# Is_quarter_start                          False                False
# Is_year_end                               False                False
# Is_year_start                             False                False
# Elapsed                              1438300800           1438300800
# StoreType                                     a                    c
# Assortment                                    a                    c
# CompetitionDistance                       14130                  620
# CompetitionOpenSinceMonth                    12                    9
# CompetitionOpenSinceYear                   2006                 2009
# Promo2                                        1                    0
# Promo2SinceWeek                              14                  NaN
# Promo2SinceYear                            2011                  NaN
# ...                                         ...                  ...
# Max_Humidity                                100                   94
# Mean_Humidity                                61                   61
# Min_Humidity                                 24                   30
# Max_Sea_Level_PressurehPa                  1022                 1019
# Mean_Sea_Level_PressurehPa                 1019                 1017
# Min_Sea_Level_PressurehPa                  1017                 1014
# Max_VisibilityKm                             31                   10
# Mean_VisibilityKm                            14                   10
# Min_VisibilitykM                             10                   10
# Max_Wind_SpeedKm_h                           14                   23
# Mean_Wind_SpeedKm_h                           5                   16
# Max_Gust_SpeedKm_h                          NaN                  NaN
# Precipitationmm                               0                    0
# CloudCover                                    2                    6
# Events                                      Fog                  NaN
# WindDirDegrees                              354                  282
# StateName                    NordrheinWestfalen               Berlin
# Year_y                                     2015                 2015
# Month_y                                       7                    7
# Week_y                                       31                   31
# Day_y                                        31                   31
# Dayofweek_y                                   4                    4
# Dayofyear_y                                 212                  212
# Is_month_end_y                             True                 True
# Is_month_start_y                          False                False
# Is_quarter_end_y                          False                False
# Is_quarter_start_y                        False                False
# Is_year_end_y                             False                False
# Is_year_start_y                           False                False
# Elapsed_y                            1438300800           1438300800
#
#                                               4
# Store                                         5
# DayOfWeek                                     5
# Date                        2015-07-31 00:00:00
# Sales                                      4822
# Customers                                   559
# Open                                          1
# Promo                                         1
# StateHoliday                              False
# SchoolHoliday                                 1
# Year                                       2015
# Month                                         7
# Week                                         31
# Day                                          31
# Dayofweek                                     4
# Dayofyear                                   212
# Is_month_end                               True
# Is_month_start                            False
# Is_quarter_end                            False
# Is_quarter_start                          False
# Is_year_end                               False
# Is_year_start                             False
# Elapsed                              1438300800
# StoreType                                     a
# Assortment                                    a
# CompetitionDistance                       29910
# CompetitionOpenSinceMonth                     4
# CompetitionOpenSinceYear                   2015
# Promo2                                        0
# Promo2SinceWeek                             NaN
# Promo2SinceYear                             NaN
# ...                                         ...
# Max_Humidity                                 82
# Mean_Humidity                                55
# Min_Humidity                                 26
# Max_Sea_Level_PressurehPa                  1020
# Mean_Sea_Level_PressurehPa                 1018
# Min_Sea_Level_PressurehPa                  1016
# Max_VisibilityKm                             10
# Mean_VisibilityKm                            10
# Min_VisibilitykM                             10
# Max_Wind_SpeedKm_h                           14
# Mean_Wind_SpeedKm_h                          11
# Max_Gust_SpeedKm_h                          NaN
# Precipitationmm                               0
# CloudCover                                    4
# Events                                      NaN
# WindDirDegrees                              290
# StateName                               Sachsen
# Year_y                                     2015
# Month_y                                       7
# Week_y                                       31
# Day_y                                        31
# Dayofweek_y                                   4
# Dayofyear_y                                 212
# Is_month_end_y                             True
# Is_month_start_y                          False
# Is_quarter_end_y                          False
# Is_quarter_start_y                        False
# Is_year_end_y                             False
# Is_year_start_y                           False
# Elapsed_y                            1438300800
#
# [100 rows x 5 columns]

# %%
joined_test.head().T
# Out:
#                                               0                    1  \
# Id                                            1                    2
# Store                                         1                    3
# DayOfWeek                                     4                    4
# Date                        2015-09-17 00:00:00  2015-09-17 00:00:00
# Open                                          1                    1
# Promo                                         1                    1
# StateHoliday                              False                False
# SchoolHoliday                                 0                    0
# Year                                       2015                 2015
# Month                                         9                    9
# Week                                         38                   38
# Day                                          17                   17
# Dayofweek                                     3                    3
# Dayofyear                                   260                  260
# Is_month_end                              False                False
# Is_month_start                            False                False
# Is_quarter_end                            False                False
# Is_quarter_start                          False                False
# Is_year_end                               False                False
# Is_year_start                             False                False
# Elapsed                              1442448000           1442448000
# StoreType                                     c                    a
# Assortment                                    a                    a
# CompetitionDistance                        1270                14130
# CompetitionOpenSinceMonth                     9                   12
# CompetitionOpenSinceYear                   2008                 2006
# Promo2                                        0                    1
# Promo2SinceWeek                             NaN                   14
# Promo2SinceYear                             NaN                 2011
# PromoInterval                               NaN      Jan,Apr,Jul,Oct
# ...                                         ...                  ...
# Max_Humidity                                100                  100
# Mean_Humidity                                95                   78
# Min_Humidity                                 88                   58
# Max_Sea_Level_PressurehPa                  1013                 1010
# Mean_Sea_Level_PressurehPa                 1004                 1000
# Min_Sea_Level_PressurehPa                   999                  993
# Max_VisibilityKm                             31                   26
# Mean_VisibilityKm                            12                   12
# Min_VisibilitykM                              7                    8
# Max_Wind_SpeedKm_h                           29                   37
# Mean_Wind_SpeedKm_h                          14                   26
# Max_Gust_SpeedKm_h                          NaN                   53
# Precipitationmm                            7.11                 3.05
# CloudCover                                    6                    6
# Events                                     Rain                 Rain
# WindDirDegrees                              191                  187
# StateName                                Hessen   NordrheinWestfalen
# Year_y                                     2015                 2015
# Month_y                                       9                    9
# Week_y                                       38                   38
# Day_y                                        17                   17
# Dayofweek_y                                   3                    3
# Dayofyear_y                                 260                  260
# Is_month_end_y                            False                False
# Is_month_start_y                          False                False
# Is_quarter_end_y                          False                False
# Is_quarter_start_y                        False                False
# Is_year_end_y                             False                False
# Is_year_start_y                           False                False
# Elapsed_y                            1442448000           1442448000
#
#                                               2                    3  \
# Id                                            3                    4
# Store                                         7                    8
# DayOfWeek                                     4                    4
# Date                        2015-09-17 00:00:00  2015-09-17 00:00:00
# Open                                          1                    1
# Promo                                         1                    1
# StateHoliday                              False                False
# SchoolHoliday                                 0                    0
# Year                                       2015                 2015
# Month                                         9                    9
# Week                                         38                   38
# Day                                          17                   17
# Dayofweek                                     3                    3
# Dayofyear                                   260                  260
# Is_month_end                              False                False
# Is_month_start                            False                False
# Is_quarter_end                            False                False
# Is_quarter_start                          False                False
# Is_year_end                               False                False
# Is_year_start                             False                False
# Elapsed                              1442448000           1442448000
# StoreType                                     a                    a
# Assortment                                    c                    a
# CompetitionDistance                       24000                 7520
# CompetitionOpenSinceMonth                     4                   10
# CompetitionOpenSinceYear                   2013                 2014
# Promo2                                        0                    0
# Promo2SinceWeek                             NaN                  NaN
# Promo2SinceYear                             NaN                  NaN
# PromoInterval                               NaN                  NaN
# ...                                         ...                  ...
# Max_Humidity                                 96                   96
# Mean_Humidity                                73                   73
# Min_Humidity                                 61                   61
# Max_Sea_Level_PressurehPa                  1003                 1003
# Mean_Sea_Level_PressurehPa                  998                  998
# Min_Sea_Level_PressurehPa                   994                  994
# Max_VisibilityKm                             26                   26
# Mean_VisibilityKm                            10                   10
# Min_VisibilitykM                              2                    2
# Max_Wind_SpeedKm_h                           29                   29
# Mean_Wind_SpeedKm_h                          14                   14
# Max_Gust_SpeedKm_h                           45                   45
# Precipitationmm                            0.76                 0.76
# CloudCover                                    5                    5
# Events                                     Rain                 Rain
# WindDirDegrees                              209                  209
# StateName                     SchleswigHolstein    SchleswigHolstein
# Year_y                                     2015                 2015
# Month_y                                       9                    9
# Week_y                                       38                   38
# Day_y                                        17                   17
# Dayofweek_y                                   3                    3
# Dayofyear_y                                 260                  260
# Is_month_end_y                            False                False
# Is_month_start_y                          False                False
# Is_quarter_end_y                          False                False
# Is_quarter_start_y                        False                False
# Is_year_end_y                             False                False
# Is_year_start_y                           False                False
# Elapsed_y                            1442448000           1442448000
#
#                                               4
# Id                                            5
# Store                                         9
# DayOfWeek                                     4
# Date                        2015-09-17 00:00:00
# Open                                          1
# Promo                                         1
# StateHoliday                              False
# SchoolHoliday                                 0
# Year                                       2015
# Month                                         9
# Week                                         38
# Day                                          17
# Dayofweek                                     3
# Dayofyear                                   260
# Is_month_end                              False
# Is_month_start                            False
# Is_quarter_end                            False
# Is_quarter_start                          False
# Is_year_end                               False
# Is_year_start                             False
# Elapsed                              1442448000
# StoreType                                     a
# Assortment                                    c
# CompetitionDistance                        2030
# CompetitionOpenSinceMonth                     8
# CompetitionOpenSinceYear                   2000
# Promo2                                        0
# Promo2SinceWeek                             NaN
# Promo2SinceYear                             NaN
# PromoInterval                               NaN
# ...                                         ...
# Max_Humidity                                100
# Mean_Humidity                                78
# Min_Humidity                                 58
# Max_Sea_Level_PressurehPa                  1010
# Mean_Sea_Level_PressurehPa                 1000
# Min_Sea_Level_PressurehPa                   993
# Max_VisibilityKm                             26
# Mean_VisibilityKm                            12
# Min_VisibilitykM                              8
# Max_Wind_SpeedKm_h                           37
# Mean_Wind_SpeedKm_h                          26
# Max_Gust_SpeedKm_h                           53
# Precipitationmm                            3.05
# CloudCover                                    6
# Events                                     Rain
# WindDirDegrees                              187
# StateName                    NordrheinWestfalen
# Year_y                                     2015
# Month_y                                       9
# Week_y                                       38
# Day_y                                        17
# Dayofweek_y                                   3
# Dayofyear_y                                 260
# Is_month_end_y                            False
# Is_month_start_y                          False
# Is_quarter_end_y                          False
# Is_quarter_start_y                        False
# Is_year_end_y                             False
# Is_year_start_y                           False
# Elapsed_y                            1442448000
#
# [99 rows x 5 columns]

# %%
for df in (joined, joined_test):
    for c in df.columns:
        if c.endswith('_y'):
            if c in df.columns: df.drop(c, inplace=True, axis=1)

# %%
joined.head().T
# Out:
#                                               0                    1  \
# Store                                         1                    2
# DayOfWeek                                     5                    5
# Date                        2015-07-31 00:00:00  2015-07-31 00:00:00
# Sales                                      5263                 6064
# Customers                                   555                  625
# Open                                          1                    1
# Promo                                         1                    1
# StateHoliday                              False                False
# SchoolHoliday                                 1                    1
# Year                                       2015                 2015
# Month                                         7                    7
# Week                                         31                   31
# Day                                          31                   31
# Dayofweek                                     4                    4
# Dayofyear                                   212                  212
# Is_month_end                               True                 True
# Is_month_start                            False                False
# Is_quarter_end                            False                False
# Is_quarter_start                          False                False
# Is_year_end                               False                False
# Is_year_start                             False                False
# Elapsed                              1438300800           1438300800
# StoreType                                     c                    a
# Assortment                                    a                    a
# CompetitionDistance                        1270                  570
# CompetitionOpenSinceMonth                     9                   11
# CompetitionOpenSinceYear                   2008                 2007
# Promo2                                        0                    1
# Promo2SinceWeek                             NaN                   13
# Promo2SinceYear                             NaN                 2010
# ...                                         ...                  ...
# Is_month_end_DE                           False                False
# Is_month_start_DE                         False                False
# Is_quarter_end_DE                         False                False
# Is_quarter_start_DE                       False                False
# Is_year_end_DE                            False                False
# Is_year_start_DE                          False                False
# Elapsed_DE                           1438473600           1438473600
# Max_TemperatureC                             23                   19
# Mean_TemperatureC                            16                   13
# Min_TemperatureC                              8                    7
# Dew_PointC                                    9                    9
# MeanDew_PointC                                6                    6
# Min_DewpointC                                 3                    3
# Max_Humidity                                 98                  100
# Mean_Humidity                                54                   62
# Min_Humidity                                 18                   25
# Max_Sea_Level_PressurehPa                  1021                 1021
# Mean_Sea_Level_PressurehPa                 1018                 1019
# Min_Sea_Level_PressurehPa                  1015                 1017
# Max_VisibilityKm                             31                   10
# Mean_VisibilityKm                            15                   10
# Min_VisibilitykM                             10                   10
# Max_Wind_SpeedKm_h                           24                   14
# Mean_Wind_SpeedKm_h                          11                   11
# Max_Gust_SpeedKm_h                          NaN                  NaN
# Precipitationmm                               0                    0
# CloudCover                                    1                    4
# Events                                      Fog                  Fog
# WindDirDegrees                               13                  309
# StateName                                Hessen           Thueringen
#
#                                               2                    3  \
# Store                                         3                    4
# DayOfWeek                                     5                    5
# Date                        2015-07-31 00:00:00  2015-07-31 00:00:00
# Sales                                      8314                13995
# Customers                                   821                 1498
# Open                                          1                    1
# Promo                                         1                    1
# StateHoliday                              False                False
# SchoolHoliday                                 1                    1
# Year                                       2015                 2015
# Month                                         7                    7
# Week                                         31                   31
# Day                                          31                   31
# Dayofweek                                     4                    4
# Dayofyear                                   212                  212
# Is_month_end                               True                 True
# Is_month_start                            False                False
# Is_quarter_end                            False                False
# Is_quarter_start                          False                False
# Is_year_end                               False                False
# Is_year_start                             False                False
# Elapsed                              1438300800           1438300800
# StoreType                                     a                    c
# Assortment                                    a                    c
# CompetitionDistance                       14130                  620
# CompetitionOpenSinceMonth                    12                    9
# CompetitionOpenSinceYear                   2006                 2009
# Promo2                                        1                    0
# Promo2SinceWeek                              14                  NaN
# Promo2SinceYear                            2011                  NaN
# ...                                         ...                  ...
# Is_month_end_DE                           False                False
# Is_month_start_DE                         False                False
# Is_quarter_end_DE                         False                False
# Is_quarter_start_DE                       False                False
# Is_year_end_DE                            False                False
# Is_year_start_DE                          False                False
# Elapsed_DE                           1438473600           1438473600
# Max_TemperatureC                             21                   19
# Mean_TemperatureC                            13                   14
# Min_TemperatureC                              6                    9
# Dew_PointC                                   10                    9
# MeanDew_PointC                                7                    7
# Min_DewpointC                                 4                    4
# Max_Humidity                                100                   94
# Mean_Humidity                                61                   61
# Min_Humidity                                 24                   30
# Max_Sea_Level_PressurehPa                  1022                 1019
# Mean_Sea_Level_PressurehPa                 1019                 1017
# Min_Sea_Level_PressurehPa                  1017                 1014
# Max_VisibilityKm                             31                   10
# Mean_VisibilityKm                            14                   10
# Min_VisibilitykM                             10                   10
# Max_Wind_SpeedKm_h                           14                   23
# Mean_Wind_SpeedKm_h                           5                   16
# Max_Gust_SpeedKm_h                          NaN                  NaN
# Precipitationmm                               0                    0
# CloudCover                                    2                    6
# Events                                      Fog                  NaN
# WindDirDegrees                              354                  282
# StateName                    NordrheinWestfalen               Berlin
#
#                                               4
# Store                                         5
# DayOfWeek                                     5
# Date                        2015-07-31 00:00:00
# Sales                                      4822
# Customers                                   559
# Open                                          1
# Promo                                         1
# StateHoliday                              False
# SchoolHoliday                                 1
# Year                                       2015
# Month                                         7
# Week                                         31
# Day                                          31
# Dayofweek                                     4
# Dayofyear                                   212
# Is_month_end                               True
# Is_month_start                            False
# Is_quarter_end                            False
# Is_quarter_start                          False
# Is_year_end                               False
# Is_year_start                             False
# Elapsed                              1438300800
# StoreType                                     a
# Assortment                                    a
# CompetitionDistance                       29910
# CompetitionOpenSinceMonth                     4
# CompetitionOpenSinceYear                   2015
# Promo2                                        0
# Promo2SinceWeek                             NaN
# Promo2SinceYear                             NaN
# ...                                         ...
# Is_month_end_DE                           False
# Is_month_start_DE                         False
# Is_quarter_end_DE                         False
# Is_quarter_start_DE                       False
# Is_year_end_DE                            False
# Is_year_start_DE                          False
# Elapsed_DE                           1438473600
# Max_TemperatureC                             20
# Mean_TemperatureC                            15
# Min_TemperatureC                             10
# Dew_PointC                                    8
# MeanDew_PointC                                6
# Min_DewpointC                                 5
# Max_Humidity                                 82
# Mean_Humidity                                55
# Min_Humidity                                 26
# Max_Sea_Level_PressurehPa                  1020
# Mean_Sea_Level_PressurehPa                 1018
# Min_Sea_Level_PressurehPa                  1016
# Max_VisibilityKm                             10
# Mean_VisibilityKm                            10
# Min_VisibilitykM                             10
# Max_Wind_SpeedKm_h                           14
# Mean_Wind_SpeedKm_h                          11
# Max_Gust_SpeedKm_h                          NaN
# Precipitationmm                               0
# CloudCover                                    4
# Events                                      NaN
# WindDirDegrees                              290
# StateName                               Sachsen
#
# [74 rows x 5 columns]

# %%
joined.head().T
# Out:
#                                               0                    1  \
# Store                                         1                    2
# DayOfWeek                                     5                    5
# Date                        2015-07-31 00:00:00  2015-07-31 00:00:00
# Sales                                      5263                 6064
# Customers                                   555                  625
# Open                                          1                    1
# Promo                                         1                    1
# StateHoliday                              False                False
# SchoolHoliday                                 1                    1
# Year                                       2015                 2015
# Month                                         7                    7
# Week                                         31                   31
# Day                                          31                   31
# Dayofweek                                     4                    4
# Dayofyear                                   212                  212
# Is_month_end                               True                 True
# Is_month_start                            False                False
# Is_quarter_end                            False                False
# Is_quarter_start                          False                False
# Is_year_end                               False                False
# Is_year_start                             False                False
# Elapsed                              1438300800           1438300800
# StoreType                                     c                    a
# Assortment                                    a                    a
# CompetitionDistance                        1270                  570
# CompetitionOpenSinceMonth                     9                   11
# CompetitionOpenSinceYear                   2008                 2007
# Promo2                                        0                    1
# Promo2SinceWeek                             NaN                   13
# Promo2SinceYear                             NaN                 2010
# ...                                         ...                  ...
# Is_month_end_DE                           False                False
# Is_month_start_DE                         False                False
# Is_quarter_end_DE                         False                False
# Is_quarter_start_DE                       False                False
# Is_year_end_DE                            False                False
# Is_year_start_DE                          False                False
# Elapsed_DE                           1438473600           1438473600
# Max_TemperatureC                             23                   19
# Mean_TemperatureC                            16                   13
# Min_TemperatureC                              8                    7
# Dew_PointC                                    9                    9
# MeanDew_PointC                                6                    6
# Min_DewpointC                                 3                    3
# Max_Humidity                                 98                  100
# Mean_Humidity                                54                   62
# Min_Humidity                                 18                   25
# Max_Sea_Level_PressurehPa                  1021                 1021
# Mean_Sea_Level_PressurehPa                 1018                 1019
# Min_Sea_Level_PressurehPa                  1015                 1017
# Max_VisibilityKm                             31                   10
# Mean_VisibilityKm                            15                   10
# Min_VisibilitykM                             10                   10
# Max_Wind_SpeedKm_h                           24                   14
# Mean_Wind_SpeedKm_h                          11                   11
# Max_Gust_SpeedKm_h                          NaN                  NaN
# Precipitationmm                               0                    0
# CloudCover                                    1                    4
# Events                                      Fog                  Fog
# WindDirDegrees                               13                  309
# StateName                                Hessen           Thueringen
#
#                                               2                    3  \
# Store                                         3                    4
# DayOfWeek                                     5                    5
# Date                        2015-07-31 00:00:00  2015-07-31 00:00:00
# Sales                                      8314                13995
# Customers                                   821                 1498
# Open                                          1                    1
# Promo                                         1                    1
# StateHoliday                              False                False
# SchoolHoliday                                 1                    1
# Year                                       2015                 2015
# Month                                         7                    7
# Week                                         31                   31
# Day                                          31                   31
# Dayofweek                                     4                    4
# Dayofyear                                   212                  212
# Is_month_end                               True                 True
# Is_month_start                            False                False
# Is_quarter_end                            False                False
# Is_quarter_start                          False                False
# Is_year_end                               False                False
# Is_year_start                             False                False
# Elapsed                              1438300800           1438300800
# StoreType                                     a                    c
# Assortment                                    a                    c
# CompetitionDistance                       14130                  620
# CompetitionOpenSinceMonth                    12                    9
# CompetitionOpenSinceYear                   2006                 2009
# Promo2                                        1                    0
# Promo2SinceWeek                              14                  NaN
# Promo2SinceYear                            2011                  NaN
# ...                                         ...                  ...
# Is_month_end_DE                           False                False
# Is_month_start_DE                         False                False
# Is_quarter_end_DE                         False                False
# Is_quarter_start_DE                       False                False
# Is_year_end_DE                            False                False
# Is_year_start_DE                          False                False
# Elapsed_DE                           1438473600           1438473600
# Max_TemperatureC                             21                   19
# Mean_TemperatureC                            13                   14
# Min_TemperatureC                              6                    9
# Dew_PointC                                   10                    9
# MeanDew_PointC                                7                    7
# Min_DewpointC                                 4                    4
# Max_Humidity                                100                   94
# Mean_Humidity                                61                   61
# Min_Humidity                                 24                   30
# Max_Sea_Level_PressurehPa                  1022                 1019
# Mean_Sea_Level_PressurehPa                 1019                 1017
# Min_Sea_Level_PressurehPa                  1017                 1014
# Max_VisibilityKm                             31                   10
# Mean_VisibilityKm                            14                   10
# Min_VisibilitykM                             10                   10
# Max_Wind_SpeedKm_h                           14                   23
# Mean_Wind_SpeedKm_h                           5                   16
# Max_Gust_SpeedKm_h                          NaN                  NaN
# Precipitationmm                               0                    0
# CloudCover                                    2                    6
# Events                                      Fog                  NaN
# WindDirDegrees                              354                  282
# StateName                    NordrheinWestfalen               Berlin
#
#                                               4
# Store                                         5
# DayOfWeek                                     5
# Date                        2015-07-31 00:00:00
# Sales                                      4822
# Customers                                   559
# Open                                          1
# Promo                                         1
# StateHoliday                              False
# SchoolHoliday                                 1
# Year                                       2015
# Month                                         7
# Week                                         31
# Day                                          31
# Dayofweek                                     4
# Dayofyear                                   212
# Is_month_end                               True
# Is_month_start                            False
# Is_quarter_end                            False
# Is_quarter_start                          False
# Is_year_end                               False
# Is_year_start                             False
# Elapsed                              1438300800
# StoreType                                     a
# Assortment                                    a
# CompetitionDistance                       29910
# CompetitionOpenSinceMonth                     4
# CompetitionOpenSinceYear                   2015
# Promo2                                        0
# Promo2SinceWeek                             NaN
# Promo2SinceYear                             NaN
# ...                                         ...
# Is_month_end_DE                           False
# Is_month_start_DE                         False
# Is_quarter_end_DE                         False
# Is_quarter_start_DE                       False
# Is_year_end_DE                            False
# Is_year_start_DE                          False
# Elapsed_DE                           1438473600
# Max_TemperatureC                             20
# Mean_TemperatureC                            15
# Min_TemperatureC                             10
# Dew_PointC                                    8
# MeanDew_PointC                                6
# Min_DewpointC                                 5
# Max_Humidity                                 82
# Mean_Humidity                                55
# Min_Humidity                                 26
# Max_Sea_Level_PressurehPa                  1020
# Mean_Sea_Level_PressurehPa                 1018
# Min_Sea_Level_PressurehPa                  1016
# Max_VisibilityKm                             10
# Mean_VisibilityKm                            10
# Min_VisibilitykM                             10
# Max_Wind_SpeedKm_h                           14
# Mean_Wind_SpeedKm_h                          11
# Max_Gust_SpeedKm_h                          NaN
# Precipitationmm                               0
# CloudCover                                    4
# Events                                      NaN
# WindDirDegrees                              290
# StateName                               Sachsen
#
# [74 rows x 5 columns]

# %%
for df in (joined,joined_test):
    df['CompetitionOpenSinceYear'] = df.CompetitionOpenSinceYear.fillna(1900).astype(np.int32)
    df['CompetitionOpenSinceMonth'] = df.CompetitionOpenSinceMonth.fillna(1).astype(np.int32)
    df['Promo2SinceYear'] = df.Promo2SinceYear.fillna(1900).astype(np.int32)
    df['Promo2SinceWeek'] = df.Promo2SinceWeek.fillna(1).astype(np.int32)

# %%
for df in (joined,joined_test):
    df["CompetitionOpenSince"] = pd.to_datetime(dict(year=df.CompetitionOpenSinceYear, 
                                                     month=df.CompetitionOpenSinceMonth, day=15))
    df["CompetitionDaysOpen"] = df.Date.subtract(df.CompetitionOpenSince).dt.days

# %%
for df in (joined,joined_test):
    df.loc[df.CompetitionDaysOpen<0, "CompetitionDaysOpen"] = 0
    df.loc[df.CompetitionOpenSinceYear<1990, "CompetitionDaysOpen"] = 0

# %%
for df in (joined,joined_test):
    df["CompetitionMonthsOpen"] = df["CompetitionDaysOpen"]//30
    df.loc[df.CompetitionMonthsOpen>24, "CompetitionMonthsOpen"] = 24
joined.CompetitionMonthsOpen.unique()
# Out:
# array([24,  3, 19,  9,  0, 16, 17,  7, 15, 22, 11, 13,  2, 23, 12,  4, 10,  1, 14, 20,  8, 18,  6, 21,  5])

# %%
from isoweek import Week
for df in (joined,joined_test):
    df["Promo2Since"] = pd.to_datetime(df.apply(lambda x: Week(
        x.Promo2SinceYear, x.Promo2SinceWeek).monday(), axis=1))
    df["Promo2Days"] = df.Date.subtract(df["Promo2Since"]).dt.days

# %%
for df in (joined,joined_test):
    df.loc[df.Promo2Days<0, "Promo2Days"] = 0
    df.loc[df.Promo2SinceYear<1990, "Promo2Days"] = 0
    df["Promo2Weeks"] = df["Promo2Days"]//7
    df.loc[df.Promo2Weeks<0, "Promo2Weeks"] = 0
    df.loc[df.Promo2Weeks>25, "Promo2Weeks"] = 25
    df.Promo2Weeks.unique()
# Out:
# array([ 0, 25, 17,  8, 13, 24, 16,  7, 12, 23, 15,  6, 11, 22, 14,  5, 10, 21,  4,  9, 20,  3, 19,  2, 18,  1])
# array([ 0, 25, 24, 15, 20, 23, 14, 19, 22, 13, 18, 21, 12, 17, 11, 16, 10,  9,  8])

# %%
joined.to_pickle(ROOT/'joined')
joined_test.to_pickle(ROOT/'joined_test')

# %%
joined.head().T
# Out:
#                                               0                    1  \
# Store                                         1                    2
# DayOfWeek                                     5                    5
# Date                        2015-07-31 00:00:00  2015-07-31 00:00:00
# Sales                                      5263                 6064
# Customers                                   555                  625
# Open                                          1                    1
# Promo                                         1                    1
# StateHoliday                              False                False
# SchoolHoliday                                 1                    1
# Year                                       2015                 2015
# Month                                         7                    7
# Week                                         31                   31
# Day                                          31                   31
# Dayofweek                                     4                    4
# Dayofyear                                   212                  212
# Is_month_end                               True                 True
# Is_month_start                            False                False
# Is_quarter_end                            False                False
# Is_quarter_start                          False                False
# Is_year_end                               False                False
# Is_year_start                             False                False
# Elapsed                              1438300800           1438300800
# StoreType                                     c                    a
# Assortment                                    a                    a
# CompetitionDistance                        1270                  570
# CompetitionOpenSinceMonth                     9                   11
# CompetitionOpenSinceYear                   2008                 2007
# Promo2                                        0                    1
# Promo2SinceWeek                               1                   13
# Promo2SinceYear                            1900                 2010
# ...                                         ...                  ...
# Elapsed_DE                           1438473600           1438473600
# Max_TemperatureC                             23                   19
# Mean_TemperatureC                            16                   13
# Min_TemperatureC                              8                    7
# Dew_PointC                                    9                    9
# MeanDew_PointC                                6                    6
# Min_DewpointC                                 3                    3
# Max_Humidity                                 98                  100
# Mean_Humidity                                54                   62
# Min_Humidity                                 18                   25
# Max_Sea_Level_PressurehPa                  1021                 1021
# Mean_Sea_Level_PressurehPa                 1018                 1019
# Min_Sea_Level_PressurehPa                  1015                 1017
# Max_VisibilityKm                             31                   10
# Mean_VisibilityKm                            15                   10
# Min_VisibilitykM                             10                   10
# Max_Wind_SpeedKm_h                           24                   14
# Mean_Wind_SpeedKm_h                          11                   11
# Max_Gust_SpeedKm_h                          NaN                  NaN
# Precipitationmm                               0                    0
# CloudCover                                    1                    4
# Events                                      Fog                  Fog
# WindDirDegrees                               13                  309
# StateName                                Hessen           Thueringen
# CompetitionOpenSince        2008-09-15 00:00:00  2007-11-15 00:00:00
# CompetitionDaysOpen                        2510                 2815
# CompetitionMonthsOpen                        24                   24
# Promo2Since                 1900-01-01 00:00:00  2010-03-29 00:00:00
# Promo2Days                                    0                 1950
# Promo2Weeks                                   0                   25
#
#                                               2                    3  \
# Store                                         3                    4
# DayOfWeek                                     5                    5
# Date                        2015-07-31 00:00:00  2015-07-31 00:00:00
# Sales                                      8314                13995
# Customers                                   821                 1498
# Open                                          1                    1
# Promo                                         1                    1
# StateHoliday                              False                False
# SchoolHoliday                                 1                    1
# Year                                       2015                 2015
# Month                                         7                    7
# Week                                         31                   31
# Day                                          31                   31
# Dayofweek                                     4                    4
# Dayofyear                                   212                  212
# Is_month_end                               True                 True
# Is_month_start                            False                False
# Is_quarter_end                            False                False
# Is_quarter_start                          False                False
# Is_year_end                               False                False
# Is_year_start                             False                False
# Elapsed                              1438300800           1438300800
# StoreType                                     a                    c
# Assortment                                    a                    c
# CompetitionDistance                       14130                  620
# CompetitionOpenSinceMonth                    12                    9
# CompetitionOpenSinceYear                   2006                 2009
# Promo2                                        1                    0
# Promo2SinceWeek                              14                    1
# Promo2SinceYear                            2011                 1900
# ...                                         ...                  ...
# Elapsed_DE                           1438473600           1438473600
# Max_TemperatureC                             21                   19
# Mean_TemperatureC                            13                   14
# Min_TemperatureC                              6                    9
# Dew_PointC                                   10                    9
# MeanDew_PointC                                7                    7
# Min_DewpointC                                 4                    4
# Max_Humidity                                100                   94
# Mean_Humidity                                61                   61
# Min_Humidity                                 24                   30
# Max_Sea_Level_PressurehPa                  1022                 1019
# Mean_Sea_Level_PressurehPa                 1019                 1017
# Min_Sea_Level_PressurehPa                  1017                 1014
# Max_VisibilityKm                             31                   10
# Mean_VisibilityKm                            14                   10
# Min_VisibilitykM                             10                   10
# Max_Wind_SpeedKm_h                           14                   23
# Mean_Wind_SpeedKm_h                           5                   16
# Max_Gust_SpeedKm_h                          NaN                  NaN
# Precipitationmm                               0                    0
# CloudCover                                    2                    6
# Events                                      Fog                  NaN
# WindDirDegrees                              354                  282
# StateName                    NordrheinWestfalen               Berlin
# CompetitionOpenSince        2006-12-15 00:00:00  2009-09-15 00:00:00
# CompetitionDaysOpen                        3150                 2145
# CompetitionMonthsOpen                        24                   24
# Promo2Since                 2011-04-04 00:00:00  1900-01-01 00:00:00
# Promo2Days                                 1579                    0
# Promo2Weeks                                  25                    0
#
#                                               4
# Store                                         5
# DayOfWeek                                     5
# Date                        2015-07-31 00:00:00
# Sales                                      4822
# Customers                                   559
# Open                                          1
# Promo                                         1
# StateHoliday                              False
# SchoolHoliday                                 1
# Year                                       2015
# Month                                         7
# Week                                         31
# Day                                          31
# Dayofweek                                     4
# Dayofyear                                   212
# Is_month_end                               True
# Is_month_start                            False
# Is_quarter_end                            False
# Is_quarter_start                          False
# Is_year_end                               False
# Is_year_start                             False
# Elapsed                              1438300800
# StoreType                                     a
# Assortment                                    a
# CompetitionDistance                       29910
# CompetitionOpenSinceMonth                     4
# CompetitionOpenSinceYear                   2015
# Promo2                                        0
# Promo2SinceWeek                               1
# Promo2SinceYear                            1900
# ...                                         ...
# Elapsed_DE                           1438473600
# Max_TemperatureC                             20
# Mean_TemperatureC                            15
# Min_TemperatureC                             10
# Dew_PointC                                    8
# MeanDew_PointC                                6
# Min_DewpointC                                 5
# Max_Humidity                                 82
# Mean_Humidity                                55
# Min_Humidity                                 26
# Max_Sea_Level_PressurehPa                  1020
# Mean_Sea_Level_PressurehPa                 1018
# Min_Sea_Level_PressurehPa                  1016
# Max_VisibilityKm                             10
# Mean_VisibilityKm                            10
# Min_VisibilitykM                             10
# Max_Wind_SpeedKm_h                           14
# Mean_Wind_SpeedKm_h                          11
# Max_Gust_SpeedKm_h                          NaN
# Precipitationmm                               0
# CloudCover                                    4
# Events                                      NaN
# WindDirDegrees                              290
# StateName                               Sachsen
# CompetitionOpenSince        2015-04-15 00:00:00
# CompetitionDaysOpen                         107
# CompetitionMonthsOpen                         3
# Promo2Since                 1900-01-01 00:00:00
# Promo2Days                                    0
# Promo2Weeks                                   0
#
# [80 rows x 5 columns]

# %%
joined_test.head().T
# Out:
#                                               0                    1  \
# Id                                            1                    2
# Store                                         1                    3
# DayOfWeek                                     4                    4
# Date                        2015-09-17 00:00:00  2015-09-17 00:00:00
# Open                                          1                    1
# Promo                                         1                    1
# StateHoliday                              False                False
# SchoolHoliday                                 0                    0
# Year                                       2015                 2015
# Month                                         9                    9
# Week                                         38                   38
# Day                                          17                   17
# Dayofweek                                     3                    3
# Dayofyear                                   260                  260
# Is_month_end                              False                False
# Is_month_start                            False                False
# Is_quarter_end                            False                False
# Is_quarter_start                          False                False
# Is_year_end                               False                False
# Is_year_start                             False                False
# Elapsed                              1442448000           1442448000
# StoreType                                     c                    a
# Assortment                                    a                    a
# CompetitionDistance                        1270                14130
# CompetitionOpenSinceMonth                     9                   12
# CompetitionOpenSinceYear                   2008                 2006
# Promo2                                        0                    1
# Promo2SinceWeek                               1                   14
# Promo2SinceYear                            1900                 2011
# PromoInterval                               NaN      Jan,Apr,Jul,Oct
# ...                                         ...                  ...
# Elapsed_DE                           1442707200           1442707200
# Max_TemperatureC                             16                   17
# Mean_TemperatureC                            14                   14
# Min_TemperatureC                             13                   12
# Dew_PointC                                   16                   14
# MeanDew_PointC                               14                   12
# Min_DewpointC                                12                   11
# Max_Humidity                                100                  100
# Mean_Humidity                                95                   78
# Min_Humidity                                 88                   58
# Max_Sea_Level_PressurehPa                  1013                 1010
# Mean_Sea_Level_PressurehPa                 1004                 1000
# Min_Sea_Level_PressurehPa                   999                  993
# Max_VisibilityKm                             31                   26
# Mean_VisibilityKm                            12                   12
# Min_VisibilitykM                              7                    8
# Max_Wind_SpeedKm_h                           29                   37
# Mean_Wind_SpeedKm_h                          14                   26
# Max_Gust_SpeedKm_h                          NaN                   53
# Precipitationmm                            7.11                 3.05
# CloudCover                                    6                    6
# Events                                     Rain                 Rain
# WindDirDegrees                              191                  187
# StateName                                Hessen   NordrheinWestfalen
# CompetitionOpenSince        2008-09-15 00:00:00  2006-12-15 00:00:00
# CompetitionDaysOpen                        2558                 3198
# CompetitionMonthsOpen                        24                   24
# Promo2Since                 1900-01-01 00:00:00  2011-04-04 00:00:00
# Promo2Days                                    0                 1627
# Promo2Weeks                                   0                   25
#
#                                               2                    3  \
# Id                                            3                    4
# Store                                         7                    8
# DayOfWeek                                     4                    4
# Date                        2015-09-17 00:00:00  2015-09-17 00:00:00
# Open                                          1                    1
# Promo                                         1                    1
# StateHoliday                              False                False
# SchoolHoliday                                 0                    0
# Year                                       2015                 2015
# Month                                         9                    9
# Week                                         38                   38
# Day                                          17                   17
# Dayofweek                                     3                    3
# Dayofyear                                   260                  260
# Is_month_end                              False                False
# Is_month_start                            False                False
# Is_quarter_end                            False                False
# Is_quarter_start                          False                False
# Is_year_end                               False                False
# Is_year_start                             False                False
# Elapsed                              1442448000           1442448000
# StoreType                                     a                    a
# Assortment                                    c                    a
# CompetitionDistance                       24000                 7520
# CompetitionOpenSinceMonth                     4                   10
# CompetitionOpenSinceYear                   2013                 2014
# Promo2                                        0                    0
# Promo2SinceWeek                               1                    1
# Promo2SinceYear                            1900                 1900
# PromoInterval                               NaN                  NaN
# ...                                         ...                  ...
# Elapsed_DE                           1442707200           1442707200
# Max_TemperatureC                             18                   18
# Mean_TemperatureC                            16                   16
# Min_TemperatureC                             13                   13
# Dew_PointC                                   16                   16
# MeanDew_PointC                               13                   13
# Min_DewpointC                                11                   11
# Max_Humidity                                 96                   96
# Mean_Humidity                                73                   73
# Min_Humidity                                 61                   61
# Max_Sea_Level_PressurehPa                  1003                 1003
# Mean_Sea_Level_PressurehPa                  998                  998
# Min_Sea_Level_PressurehPa                   994                  994
# Max_VisibilityKm                             26                   26
# Mean_VisibilityKm                            10                   10
# Min_VisibilitykM                              2                    2
# Max_Wind_SpeedKm_h                           29                   29
# Mean_Wind_SpeedKm_h                          14                   14
# Max_Gust_SpeedKm_h                           45                   45
# Precipitationmm                            0.76                 0.76
# CloudCover                                    5                    5
# Events                                     Rain                 Rain
# WindDirDegrees                              209                  209
# StateName                     SchleswigHolstein    SchleswigHolstein
# CompetitionOpenSince        2013-04-15 00:00:00  2014-10-15 00:00:00
# CompetitionDaysOpen                         885                  337
# CompetitionMonthsOpen                        24                   11
# Promo2Since                 1900-01-01 00:00:00  1900-01-01 00:00:00
# Promo2Days                                    0                    0
# Promo2Weeks                                   0                    0
#
#                                               4
# Id                                            5
# Store                                         9
# DayOfWeek                                     4
# Date                        2015-09-17 00:00:00
# Open                                          1
# Promo                                         1
# StateHoliday                              False
# SchoolHoliday                                 0
# Year                                       2015
# Month                                         9
# Week                                         38
# Day                                          17
# Dayofweek                                     3
# Dayofyear                                   260
# Is_month_end                              False
# Is_month_start                            False
# Is_quarter_end                            False
# Is_quarter_start                          False
# Is_year_end                               False
# Is_year_start                             False
# Elapsed                              1442448000
# StoreType                                     a
# Assortment                                    c
# CompetitionDistance                        2030
# CompetitionOpenSinceMonth                     8
# CompetitionOpenSinceYear                   2000
# Promo2                                        0
# Promo2SinceWeek                               1
# Promo2SinceYear                            1900
# PromoInterval                               NaN
# ...                                         ...
# Elapsed_DE                           1442707200
# Max_TemperatureC                             17
# Mean_TemperatureC                            14
# Min_TemperatureC                             12
# Dew_PointC                                   14
# MeanDew_PointC                               12
# Min_DewpointC                                11
# Max_Humidity                                100
# Mean_Humidity                                78
# Min_Humidity                                 58
# Max_Sea_Level_PressurehPa                  1010
# Mean_Sea_Level_PressurehPa                 1000
# Min_Sea_Level_PressurehPa                   993
# Max_VisibilityKm                             26
# Mean_VisibilityKm                            12
# Min_VisibilitykM                              8
# Max_Wind_SpeedKm_h                           37
# Mean_Wind_SpeedKm_h                          26
# Max_Gust_SpeedKm_h                           53
# Precipitationmm                            3.05
# CloudCover                                    6
# Events                                     Rain
# WindDirDegrees                              187
# StateName                    NordrheinWestfalen
# CompetitionOpenSince        2000-08-15 00:00:00
# CompetitionDaysOpen                        5511
# CompetitionMonthsOpen                        24
# Promo2Since                 1900-01-01 00:00:00
# Promo2Days                                    0
# Promo2Weeks                                   0
#
# [79 rows x 5 columns]

# %%
def get_elapsed(fld, pre):
    day1 = np.timedelta64(1, 'D')
    last_date = np.datetime64()
    last_store = 0
    res = []

    for s,v,d in zip(df.Store.values,df[fld].values, df.Date.values):
        if s != last_store:
            last_date = np.datetime64()
            last_store = s
        if v: last_date = d
        res.append(((d-last_date).astype('timedelta64[D]') / day1))
    df[pre+fld] = res

# %%
columns = ["Date", "Store", "Promo", "StateHoliday", "SchoolHoliday"]

# %%
df = train[columns].append(test[columns])

# %%
fld = 'SchoolHoliday'
df = df.sort_values(['Store', 'Date'])
get_elapsed(fld, 'After')
df = df.sort_values(['Store', 'Date'], ascending=[True, False])
get_elapsed(fld, 'Before')

# %%
fld = 'StateHoliday'
df = df.sort_values(['Store', 'Date'])
get_elapsed(fld, 'After')
df = df.sort_values(['Store', 'Date'], ascending=[True, False])
get_elapsed(fld, 'Before')

# %%
fld = 'Promo'
df = df.sort_values(['Store', 'Date'])
get_elapsed(fld, 'After')
df = df.sort_values(['Store', 'Date'], ascending=[True, False])
get_elapsed(fld, 'Before')

# %%
df = df.set_index("Date")

# %%
columns = ['SchoolHoliday', 'StateHoliday', 'Promo']

# %%
for o in ['Before', 'After']:
    for p in columns:
        a = o+p
        df[a] = df[a].fillna(0).astype(int)

# %%
bwd = df[['Store']+columns].sort_index().groupby("Store").rolling(7, min_periods=1).sum()

# %%
fwd = df[['Store']+columns].sort_index(ascending=False
                                      ).groupby("Store").rolling(7, min_periods=1).sum()

# %%
bwd.drop('Store',1,inplace=True)
bwd.reset_index(inplace=True)

# %%
fwd.drop('Store',1,inplace=True)
fwd.reset_index(inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df = df.merge(bwd, 'left', ['Date', 'Store'], suffixes=['', '_bw'])
df = df.merge(fwd, 'left', ['Date', 'Store'], suffixes=['', '_fw'])

# %%
df.drop(columns,1,inplace=True)

# %%
df.head()
# Out:
#         Date  Store  AfterSchoolHoliday  BeforeSchoolHoliday  \
# 0 2015-09-17      1                  13                    0
# 1 2015-09-16      1                  12                    0
# 2 2015-09-15      1                  11                    0
# 3 2015-09-14      1                  10                    0
# 4 2015-09-13      1                   9                    0
#
#    AfterStateHoliday  BeforeStateHoliday  AfterPromo  BeforePromo  \
# 0                105                   0           0            0
# 1                104                   0           0            0
# 2                103                   0           0            0
# 3                102                   0           0            0
# 4                101                   0           9           -1
#
#    SchoolHoliday_bw  StateHoliday_bw  Promo_bw  SchoolHoliday_fw  \
# 0               0.0              0.0       4.0               0.0
# 1               0.0              0.0       3.0               0.0
# 2               0.0              0.0       2.0               0.0
# 3               0.0              0.0       1.0               0.0
# 4               0.0              0.0       0.0               0.0
#
#    StateHoliday_fw  Promo_fw
# 0              0.0       1.0
# 1              0.0       2.0
# 2              0.0       3.0
# 3              0.0       4.0
# 4              0.0       4.0

# %%
df.to_pickle(ROOT/'df')

# %%
df["Date"] = pd.to_datetime(df.Date)

# %%
df.columns
# Out:
# Index(['Date', 'Store', 'AfterSchoolHoliday', 'BeforeSchoolHoliday',
#        'AfterStateHoliday', 'BeforeStateHoliday', 'AfterPromo', 'BeforePromo',
#        'SchoolHoliday_bw', 'StateHoliday_bw', 'Promo_bw', 'SchoolHoliday_fw',
#        'StateHoliday_fw', 'Promo_fw'],
#       dtype='object')

# %%
joined = pd.read_pickle(ROOT/'joined')
joined_test = pd.read_pickle(ROOT/f'joined_test')

# %%
joined = join_df(joined, df, ['Store', 'Date'])

# %%
joined_test = join_df(joined_test, df, ['Store', 'Date'])

# %%
joined = joined[joined.Sales!=0]

# %%
joined.reset_index(inplace=True)
joined_test.reset_index(inplace=True)

# %%
joined.to_pickle(ROOT/'train_clean')
joined_test.to_pickle(ROOT/'test_clean')

# %%
joined.head().T
# Out:
#                                              0                    1  \
# index                                        0                    1
# Store                                        1                    2
# DayOfWeek                                    5                    5
# Date                       2015-07-31 00:00:00  2015-07-31 00:00:00
# Sales                                     5263                 6064
# Customers                                  555                  625
# Open                                         1                    1
# Promo                                        1                    1
# StateHoliday                             False                False
# SchoolHoliday                                1                    1
# Year                                      2015                 2015
# Month                                        7                    7
# Week                                        31                   31
# Day                                         31                   31
# Dayofweek                                    4                    4
# Dayofyear                                  212                  212
# Is_month_end                              True                 True
# Is_month_start                           False                False
# Is_quarter_end                           False                False
# Is_quarter_start                         False                False
# Is_year_end                              False                False
# Is_year_start                            False                False
# Elapsed                             1438300800           1438300800
# StoreType                                    c                    a
# Assortment                                   a                    a
# CompetitionDistance                       1270                  570
# CompetitionOpenSinceMonth                    9                   11
# CompetitionOpenSinceYear                  2008                 2007
# Promo2                                       0                    1
# Promo2SinceWeek                              1                   13
# ...                                        ...                  ...
# Min_Sea_Level_PressurehPa                 1015                 1017
# Max_VisibilityKm                            31                   10
# Mean_VisibilityKm                           15                   10
# Min_VisibilitykM                            10                   10
# Max_Wind_SpeedKm_h                          24                   14
# Mean_Wind_SpeedKm_h                         11                   11
# Max_Gust_SpeedKm_h                         NaN                  NaN
# Precipitationmm                              0                    0
# CloudCover                                   1                    4
# Events                                     Fog                  Fog
# WindDirDegrees                              13                  309
# StateName                               Hessen           Thueringen
# CompetitionOpenSince       2008-09-15 00:00:00  2007-11-15 00:00:00
# CompetitionDaysOpen                       2510                 2815
# CompetitionMonthsOpen                       24                   24
# Promo2Since                1900-01-01 00:00:00  2010-03-29 00:00:00
# Promo2Days                                   0                 1950
# Promo2Weeks                                  0                   25
# AfterSchoolHoliday                           0                    0
# BeforeSchoolHoliday                          0                    0
# AfterStateHoliday                           57                   67
# BeforeStateHoliday                           0                    0
# AfterPromo                                   0                    0
# BeforePromo                                  0                    0
# SchoolHoliday_bw                             5                    5
# StateHoliday_bw                              0                    0
# Promo_bw                                     5                    5
# SchoolHoliday_fw                             7                    1
# StateHoliday_fw                              0                    0
# Promo_fw                                     5                    1
#
#                                              2                    3  \
# index                                        2                    3
# Store                                        3                    4
# DayOfWeek                                    5                    5
# Date                       2015-07-31 00:00:00  2015-07-31 00:00:00
# Sales                                     8314                13995
# Customers                                  821                 1498
# Open                                         1                    1
# Promo                                        1                    1
# StateHoliday                             False                False
# SchoolHoliday                                1                    1
# Year                                      2015                 2015
# Month                                        7                    7
# Week                                        31                   31
# Day                                         31                   31
# Dayofweek                                    4                    4
# Dayofyear                                  212                  212
# Is_month_end                              True                 True
# Is_month_start                           False                False
# Is_quarter_end                           False                False
# Is_quarter_start                         False                False
# Is_year_end                              False                False
# Is_year_start                            False                False
# Elapsed                             1438300800           1438300800
# StoreType                                    a                    c
# Assortment                                   a                    c
# CompetitionDistance                      14130                  620
# CompetitionOpenSinceMonth                   12                    9
# CompetitionOpenSinceYear                  2006                 2009
# Promo2                                       1                    0
# Promo2SinceWeek                             14                    1
# ...                                        ...                  ...
# Min_Sea_Level_PressurehPa                 1017                 1014
# Max_VisibilityKm                            31                   10
# Mean_VisibilityKm                           14                   10
# Min_VisibilitykM                            10                   10
# Max_Wind_SpeedKm_h                          14                   23
# Mean_Wind_SpeedKm_h                          5                   16
# Max_Gust_SpeedKm_h                         NaN                  NaN
# Precipitationmm                              0                    0
# CloudCover                                   2                    6
# Events                                     Fog                  NaN
# WindDirDegrees                             354                  282
# StateName                   NordrheinWestfalen               Berlin
# CompetitionOpenSince       2006-12-15 00:00:00  2009-09-15 00:00:00
# CompetitionDaysOpen                       3150                 2145
# CompetitionMonthsOpen                       24                   24
# Promo2Since                2011-04-04 00:00:00  1900-01-01 00:00:00
# Promo2Days                                1579                    0
# Promo2Weeks                                 25                    0
# AfterSchoolHoliday                           0                    0
# BeforeSchoolHoliday                          0                    0
# AfterStateHoliday                           57                   67
# BeforeStateHoliday                           0                    0
# AfterPromo                                   0                    0
# BeforePromo                                  0                    0
# SchoolHoliday_bw                             5                    5
# StateHoliday_bw                              0                    0
# Promo_bw                                     5                    5
# SchoolHoliday_fw                             5                    1
# StateHoliday_fw                              0                    0
# Promo_fw                                     5                    1
#
#                                              4
# index                                        4
# Store                                        5
# DayOfWeek                                    5
# Date                       2015-07-31 00:00:00
# Sales                                     4822
# Customers                                  559
# Open                                         1
# Promo                                        1
# StateHoliday                             False
# SchoolHoliday                                1
# Year                                      2015
# Month                                        7
# Week                                        31
# Day                                         31
# Dayofweek                                    4
# Dayofyear                                  212
# Is_month_end                              True
# Is_month_start                           False
# Is_quarter_end                           False
# Is_quarter_start                         False
# Is_year_end                              False
# Is_year_start                            False
# Elapsed                             1438300800
# StoreType                                    a
# Assortment                                   a
# CompetitionDistance                      29910
# CompetitionOpenSinceMonth                    4
# CompetitionOpenSinceYear                  2015
# Promo2                                       0
# Promo2SinceWeek                              1
# ...                                        ...
# Min_Sea_Level_PressurehPa                 1016
# Max_VisibilityKm                            10
# Mean_VisibilityKm                           10
# Min_VisibilitykM                            10
# Max_Wind_SpeedKm_h                          14
# Mean_Wind_SpeedKm_h                         11
# Max_Gust_SpeedKm_h                         NaN
# Precipitationmm                              0
# CloudCover                                   4
# Events                                     NaN
# WindDirDegrees                             290
# StateName                              Sachsen
# CompetitionOpenSince       2015-04-15 00:00:00
# CompetitionDaysOpen                        107
# CompetitionMonthsOpen                        3
# Promo2Since                1900-01-01 00:00:00
# Promo2Days                                   0
# Promo2Weeks                                  0
# AfterSchoolHoliday                           0
# BeforeSchoolHoliday                          0
# AfterStateHoliday                           57
# BeforeStateHoliday                           0
# AfterPromo                                   0
# BeforePromo                                  0
# SchoolHoliday_bw                             5
# StateHoliday_bw                              0
# Promo_bw                                     5
# SchoolHoliday_fw                             1
# StateHoliday_fw                              0
# Promo_fw                                     1
#
# [93 rows x 5 columns]

# %%
joined_test.head().T
# Out:
#                                              0                    1  \
# index                                        0                    1
# Id                                           1                    2
# Store                                        1                    3
# DayOfWeek                                    4                    4
# Date                       2015-09-17 00:00:00  2015-09-17 00:00:00
# Open                                         1                    1
# Promo                                        1                    1
# StateHoliday                             False                False
# SchoolHoliday                                0                    0
# Year                                      2015                 2015
# Month                                        9                    9
# Week                                        38                   38
# Day                                         17                   17
# Dayofweek                                    3                    3
# Dayofyear                                  260                  260
# Is_month_end                             False                False
# Is_month_start                           False                False
# Is_quarter_end                           False                False
# Is_quarter_start                         False                False
# Is_year_end                              False                False
# Is_year_start                            False                False
# Elapsed                             1442448000           1442448000
# StoreType                                    c                    a
# Assortment                                   a                    a
# CompetitionDistance                       1270                14130
# CompetitionOpenSinceMonth                    9                   12
# CompetitionOpenSinceYear                  2008                 2006
# Promo2                                       0                    1
# Promo2SinceWeek                              1                   14
# Promo2SinceYear                           1900                 2011
# ...                                        ...                  ...
# Min_Sea_Level_PressurehPa                  999                  993
# Max_VisibilityKm                            31                   26
# Mean_VisibilityKm                           12                   12
# Min_VisibilitykM                             7                    8
# Max_Wind_SpeedKm_h                          29                   37
# Mean_Wind_SpeedKm_h                         14                   26
# Max_Gust_SpeedKm_h                         NaN                   53
# Precipitationmm                           7.11                 3.05
# CloudCover                                   6                    6
# Events                                    Rain                 Rain
# WindDirDegrees                             191                  187
# StateName                               Hessen   NordrheinWestfalen
# CompetitionOpenSince       2008-09-15 00:00:00  2006-12-15 00:00:00
# CompetitionDaysOpen                       2558                 3198
# CompetitionMonthsOpen                       24                   24
# Promo2Since                1900-01-01 00:00:00  2011-04-04 00:00:00
# Promo2Days                                   0                 1627
# Promo2Weeks                                  0                   25
# AfterSchoolHoliday                          13                   37
# BeforeSchoolHoliday                          0                    0
# AfterStateHoliday                          105                  105
# BeforeStateHoliday                           0                    0
# AfterPromo                                   0                    0
# BeforePromo                                  0                    0
# SchoolHoliday_bw                             0                    0
# StateHoliday_bw                              0                    0
# Promo_bw                                     4                    4
# SchoolHoliday_fw                             0                    0
# StateHoliday_fw                              0                    0
# Promo_fw                                     1                    1
#
#                                              2                    3  \
# index                                        2                    3
# Id                                           3                    4
# Store                                        7                    8
# DayOfWeek                                    4                    4
# Date                       2015-09-17 00:00:00  2015-09-17 00:00:00
# Open                                         1                    1
# Promo                                        1                    1
# StateHoliday                             False                False
# SchoolHoliday                                0                    0
# Year                                      2015                 2015
# Month                                        9                    9
# Week                                        38                   38
# Day                                         17                   17
# Dayofweek                                    3                    3
# Dayofyear                                  260                  260
# Is_month_end                             False                False
# Is_month_start                           False                False
# Is_quarter_end                           False                False
# Is_quarter_start                         False                False
# Is_year_end                              False                False
# Is_year_start                            False                False
# Elapsed                             1442448000           1442448000
# StoreType                                    a                    a
# Assortment                                   c                    a
# CompetitionDistance                      24000                 7520
# CompetitionOpenSinceMonth                    4                   10
# CompetitionOpenSinceYear                  2013                 2014
# Promo2                                       0                    0
# Promo2SinceWeek                              1                    1
# Promo2SinceYear                           1900                 1900
# ...                                        ...                  ...
# Min_Sea_Level_PressurehPa                  994                  994
# Max_VisibilityKm                            26                   26
# Mean_VisibilityKm                           10                   10
# Min_VisibilitykM                             2                    2
# Max_Wind_SpeedKm_h                          29                   29
# Mean_Wind_SpeedKm_h                         14                   14
# Max_Gust_SpeedKm_h                          45                   45
# Precipitationmm                           0.76                 0.76
# CloudCover                                   5                    5
# Events                                    Rain                 Rain
# WindDirDegrees                             209                  209
# StateName                    SchleswigHolstein    SchleswigHolstein
# CompetitionOpenSince       2013-04-15 00:00:00  2014-10-15 00:00:00
# CompetitionDaysOpen                        885                  337
# CompetitionMonthsOpen                       24                   11
# Promo2Since                1900-01-01 00:00:00  1900-01-01 00:00:00
# Promo2Days                                   0                    0
# Promo2Weeks                                  0                    0
# AfterSchoolHoliday                          20                   20
# BeforeSchoolHoliday                          0                    0
# AfterStateHoliday                          115                  115
# BeforeStateHoliday                           0                    0
# AfterPromo                                   0                    0
# BeforePromo                                  0                    0
# SchoolHoliday_bw                             0                    0
# StateHoliday_bw                              0                    0
# Promo_bw                                     4                    4
# SchoolHoliday_fw                             0                    0
# StateHoliday_fw                              0                    0
# Promo_fw                                     1                    1
#
#                                              4
# index                                        4
# Id                                           5
# Store                                        9
# DayOfWeek                                    4
# Date                       2015-09-17 00:00:00
# Open                                         1
# Promo                                        1
# StateHoliday                             False
# SchoolHoliday                                0
# Year                                      2015
# Month                                        9
# Week                                        38
# Day                                         17
# Dayofweek                                    3
# Dayofyear                                  260
# Is_month_end                             False
# Is_month_start                           False
# Is_quarter_end                           False
# Is_quarter_start                         False
# Is_year_end                              False
# Is_year_start                            False
# Elapsed                             1442448000
# StoreType                                    a
# Assortment                                   c
# CompetitionDistance                       2030
# CompetitionOpenSinceMonth                    8
# CompetitionOpenSinceYear                  2000
# Promo2                                       0
# Promo2SinceWeek                              1
# Promo2SinceYear                           1900
# ...                                        ...
# Min_Sea_Level_PressurehPa                  993
# Max_VisibilityKm                            26
# Mean_VisibilityKm                           12
# Min_VisibilitykM                             8
# Max_Wind_SpeedKm_h                          37
# Mean_Wind_SpeedKm_h                         26
# Max_Gust_SpeedKm_h                          53
# Precipitationmm                           3.05
# CloudCover                                   6
# Events                                    Rain
# WindDirDegrees                             187
# StateName                   NordrheinWestfalen
# CompetitionOpenSince       2000-08-15 00:00:00
# CompetitionDaysOpen                       5511
# CompetitionMonthsOpen                       24
# Promo2Since                1900-01-01 00:00:00
# Promo2Days                                   0
# Promo2Weeks                                  0
# AfterSchoolHoliday                          37
# BeforeSchoolHoliday                          0
# AfterStateHoliday                          105
# BeforeStateHoliday                           0
# AfterPromo                                   0
# BeforePromo                                  0
# SchoolHoliday_bw                             0
# StateHoliday_bw                              0
# Promo_bw                                     4
# SchoolHoliday_fw                             0
# StateHoliday_fw                              0
# Promo_fw                                     1
#
# [92 rows x 5 columns]
